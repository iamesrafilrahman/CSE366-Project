# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/coffee-beans-saad/Coffee Bean.csv
# /kaggle/input/coffee-beans-saad/test/Dark/dark (2).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (95).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (45).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (8).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (83).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (15).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (98).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (91).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (22).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (23).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (75).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (55).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (11).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (39).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (100).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (33).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (79).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (44).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (48).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (21).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (25).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (43).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (76).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (57).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (62).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (4).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (46).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (24).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (59).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (99).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (84).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (88).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (9).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (49).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (93).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (58).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (3).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (17).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (80).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (35).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (1).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (86).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (68).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (34).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (29).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (65).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (87).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (56).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (38).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (30).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (47).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (42).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (18).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (41).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (72).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (53).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (74).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (37).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (63).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (19).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (66).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (26).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (27).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (85).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (13).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (78).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (82).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (40).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (69).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (7).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (50).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (61).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (97).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (16).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (20).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (31).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (96).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (6).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (52).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (73).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (81).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (10).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (12).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (67).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (51).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (32).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (36).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (92).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (70).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (77).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (28).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (71).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (5).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (64).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (90).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (60).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (14).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (89).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (94).png
# /kaggle/input/coffee-beans-saad/test/Dark/dark (54).png
# /kaggle/input/coffee-beans-saad/test/Green/green (17).png
# /kaggle/input/coffee-beans-saad/test/Green/green (99).png
# /kaggle/input/coffee-beans-saad/test/Green/green (47).png
# /kaggle/input/coffee-beans-saad/test/Green/green (81).png
# /kaggle/input/coffee-beans-saad/test/Green/green (87).png
# /kaggle/input/coffee-beans-saad/test/Green/green (98).png
# /kaggle/input/coffee-beans-saad/test/Green/green (8).png
# /kaggle/input/coffee-beans-saad/test/Green/green (30).png
# /kaggle/input/coffee-beans-saad/test/Green/green (5).png
# /kaggle/input/coffee-beans-saad/test/Green/green (69).png
# /kaggle/input/coffee-beans-saad/test/Green/green (26).png
# /kaggle/input/coffee-beans-saad/test/Green/green (25).png
# /kaggle/input/coffee-beans-saad/test/Green/green (50).png
# /kaggle/input/coffee-beans-saad/test/Green/green (43).png
# /kaggle/input/coffee-beans-saad/test/Green/green (83).png
# /kaggle/input/coffee-beans-saad/test/Green/green (6).png
# /kaggle/input/coffee-beans-saad/test/Green/green (54).png
# /kaggle/input/coffee-beans-saad/test/Green/green (100).png
# /kaggle/input/coffee-beans-saad/test/Green/green (41).png
# /kaggle/input/coffee-beans-saad/test/Green/green (88).png
# /kaggle/input/coffee-beans-saad/test/Green/green (57).png
# /kaggle/input/coffee-beans-saad/test/Green/green (35).png
# /kaggle/input/coffee-beans-saad/test/Green/green (42).png
# /kaggle/input/coffee-beans-saad/test/Green/green (85).png
# /kaggle/input/coffee-beans-saad/test/Green/green (65).png
# /kaggle/input/coffee-beans-saad/test/Green/green (64).png
# /kaggle/input/coffee-beans-saad/test/Green/green (1).png
# /kaggle/input/coffee-beans-saad/test/Green/green (13).png
# /kaggle/input/coffee-beans-saad/test/Green/green (32).png
# /kaggle/input/coffee-beans-saad/test/Green/green (66).png
# /kaggle/input/coffee-beans-saad/test/Green/green (59).png
# /kaggle/input/coffee-beans-saad/test/Green/green (92).png
# /kaggle/input/coffee-beans-saad/test/Green/green (29).png
# /kaggle/input/coffee-beans-saad/test/Green/green (68).png
# /kaggle/input/coffee-beans-saad/test/Green/green (44).png
# /kaggle/input/coffee-beans-saad/test/Green/green (9).png
# /kaggle/input/coffee-beans-saad/test/Green/green (31).png
# /kaggle/input/coffee-beans-saad/test/Green/green (39).png
# /kaggle/input/coffee-beans-saad/test/Green/green (3).png
# /kaggle/input/coffee-beans-saad/test/Green/green (74).png
# /kaggle/input/coffee-beans-saad/test/Green/green (48).png
# /kaggle/input/coffee-beans-saad/test/Green/green (71).png
# /kaggle/input/coffee-beans-saad/test/Green/green (76).png
# /kaggle/input/coffee-beans-saad/test/Green/green (93).png
# /kaggle/input/coffee-beans-saad/test/Green/green (96).png
# /kaggle/input/coffee-beans-saad/test/Green/green (2).png
# /kaggle/input/coffee-beans-saad/test/Green/green (91).png
# /kaggle/input/coffee-beans-saad/test/Green/green (49).png
# /kaggle/input/coffee-beans-saad/test/Green/green (34).png
# /kaggle/input/coffee-beans-saad/test/Green/green (14).png
# /kaggle/input/coffee-beans-saad/test/Green/green (51).png
# /kaggle/input/coffee-beans-saad/test/Green/green (33).png
# /kaggle/input/coffee-beans-saad/test/Green/green (79).png
# /kaggle/input/coffee-beans-saad/test/Green/green (55).png
# /kaggle/input/coffee-beans-saad/test/Green/green (70).png
# /kaggle/input/coffee-beans-saad/test/Green/green (60).png
# /kaggle/input/coffee-beans-saad/test/Green/green (62).png
# /kaggle/input/coffee-beans-saad/test/Green/green (21).png
# /kaggle/input/coffee-beans-saad/test/Green/green (19).png
# /kaggle/input/coffee-beans-saad/test/Green/green (37).png
# /kaggle/input/coffee-beans-saad/test/Green/green (75).png
# /kaggle/input/coffee-beans-saad/test/Green/green (89).png
# /kaggle/input/coffee-beans-saad/test/Green/green (67).png
# /kaggle/input/coffee-beans-saad/test/Green/green (20).png
# /kaggle/input/coffee-beans-saad/test/Green/green (58).png
# /kaggle/input/coffee-beans-saad/test/Green/green (63).png
# /kaggle/input/coffee-beans-saad/test/Green/green (27).png
# /kaggle/input/coffee-beans-saad/test/Green/green (90).png
# /kaggle/input/coffee-beans-saad/test/Green/green (95).png
# /kaggle/input/coffee-beans-saad/test/Green/green (4).png
# /kaggle/input/coffee-beans-saad/test/Green/green (77).png
# /kaggle/input/coffee-beans-saad/test/Green/green (97).png
# /kaggle/input/coffee-beans-saad/test/Green/green (16).png
# /kaggle/input/coffee-beans-saad/test/Green/green (15).png
# /kaggle/input/coffee-beans-saad/test/Green/green (53).png
# /kaggle/input/coffee-beans-saad/test/Green/green (84).png
# /kaggle/input/coffee-beans-saad/test/Green/green (11).png
# /kaggle/input/coffee-beans-saad/test/Green/green (94).png
# /kaggle/input/coffee-beans-saad/test/Green/green (7).png
# /kaggle/input/coffee-beans-saad/test/Green/green (10).png
# /kaggle/input/coffee-beans-saad/test/Green/green (12).png
# /kaggle/input/coffee-beans-saad/test/Green/green (78).png
# /kaggle/input/coffee-beans-saad/test/Green/green (73).png
# /kaggle/input/coffee-beans-saad/test/Green/green (56).png
# /kaggle/input/coffee-beans-saad/test/Green/green (23).png
# /kaggle/input/coffee-beans-saad/test/Green/green (52).png
# /kaggle/input/coffee-beans-saad/test/Green/green (24).png
# /kaggle/input/coffee-beans-saad/test/Green/green (38).png
# /kaggle/input/coffee-beans-saad/test/Green/green (61).png
# /kaggle/input/coffee-beans-saad/test/Green/green (45).png
# /kaggle/input/coffee-beans-saad/test/Green/green (86).png
# /kaggle/input/coffee-beans-saad/test/Green/green (28).png
# /kaggle/input/coffee-beans-saad/test/Green/green (18).png
# /kaggle/input/coffee-beans-saad/test/Green/green (36).png
# /kaggle/input/coffee-beans-saad/test/Green/green (80).png
# /kaggle/input/coffee-beans-saad/test/Green/green (82).png
# /kaggle/input/coffee-beans-saad/test/Green/green (46).png
# /kaggle/input/coffee-beans-saad/test/Green/green (40).png
# /kaggle/input/coffee-beans-saad/test/Green/green (72).png
# /kaggle/input/coffee-beans-saad/test/Green/green (22).png
# /kaggle/input/coffee-beans-saad/test/Light/light (77).png
# /kaggle/input/coffee-beans-saad/test/Light/light (95).png
# /kaggle/input/coffee-beans-saad/test/Light/light (12).png
# /kaggle/input/coffee-beans-saad/test/Light/light (39).png
# /kaggle/input/coffee-beans-saad/test/Light/light (40).png
# /kaggle/input/coffee-beans-saad/test/Light/light (61).png
# /kaggle/input/coffee-beans-saad/test/Light/light (98).png
# /kaggle/input/coffee-beans-saad/test/Light/light (100).png
# /kaggle/input/coffee-beans-saad/test/Light/light (28).png
# /kaggle/input/coffee-beans-saad/test/Light/light (7).png
# /kaggle/input/coffee-beans-saad/test/Light/light (70).png
# /kaggle/input/coffee-beans-saad/test/Light/light (38).png
# /kaggle/input/coffee-beans-saad/test/Light/light (74).png
# /kaggle/input/coffee-beans-saad/test/Light/light (27).png
# /kaggle/input/coffee-beans-saad/test/Light/light (22).png
# /kaggle/input/coffee-beans-saad/test/Light/light (4).png
# /kaggle/input/coffee-beans-saad/test/Light/light (51).png
# /kaggle/input/coffee-beans-saad/test/Light/light (63).png
# /kaggle/input/coffee-beans-saad/test/Light/light (8).png
# /kaggle/input/coffee-beans-saad/test/Light/light (58).png
# /kaggle/input/coffee-beans-saad/test/Light/light (5).png
# /kaggle/input/coffee-beans-saad/test/Light/light (15).png
# /kaggle/input/coffee-beans-saad/test/Light/light (86).png
# /kaggle/input/coffee-beans-saad/test/Light/light (76).png
# /kaggle/input/coffee-beans-saad/test/Light/light (89).png
# /kaggle/input/coffee-beans-saad/test/Light/light (85).png
# /kaggle/input/coffee-beans-saad/test/Light/light (73).png
# /kaggle/input/coffee-beans-saad/test/Light/light (21).png
# /kaggle/input/coffee-beans-saad/test/Light/light (3).png
# /kaggle/input/coffee-beans-saad/test/Light/light (46).png
# /kaggle/input/coffee-beans-saad/test/Light/light (37).png
# /kaggle/input/coffee-beans-saad/test/Light/light (11).png
# /kaggle/input/coffee-beans-saad/test/Light/light (25).png
# /kaggle/input/coffee-beans-saad/test/Light/light (59).png
# /kaggle/input/coffee-beans-saad/test/Light/light (75).png
# /kaggle/input/coffee-beans-saad/test/Light/light (60).png
# /kaggle/input/coffee-beans-saad/test/Light/light (49).png
# /kaggle/input/coffee-beans-saad/test/Light/light (82).png
# /kaggle/input/coffee-beans-saad/test/Light/light (41).png
# /kaggle/input/coffee-beans-saad/test/Light/light (2).png
# /kaggle/input/coffee-beans-saad/test/Light/light (87).png
# /kaggle/input/coffee-beans-saad/test/Light/light (65).png
# /kaggle/input/coffee-beans-saad/test/Light/light (83).png
# /kaggle/input/coffee-beans-saad/test/Light/light (56).png
# /kaggle/input/coffee-beans-saad/test/Light/light (42).png
# /kaggle/input/coffee-beans-saad/test/Light/light (50).png
# /kaggle/input/coffee-beans-saad/test/Light/light (72).png
# /kaggle/input/coffee-beans-saad/test/Light/light (69).png
# /kaggle/input/coffee-beans-saad/test/Light/light (66).png
# /kaggle/input/coffee-beans-saad/test/Light/light (20).png
# /kaggle/input/coffee-beans-saad/test/Light/light (43).png
# /kaggle/input/coffee-beans-saad/test/Light/light (31).png
# /kaggle/input/coffee-beans-saad/test/Light/light (1).png
# /kaggle/input/coffee-beans-saad/test/Light/light (36).png
# /kaggle/input/coffee-beans-saad/test/Light/light (81).png
# /kaggle/input/coffee-beans-saad/test/Light/light (78).png
# /kaggle/input/coffee-beans-saad/test/Light/light (84).png
# /kaggle/input/coffee-beans-saad/test/Light/light (6).png
# /kaggle/input/coffee-beans-saad/test/Light/light (47).png
# /kaggle/input/coffee-beans-saad/test/Light/light (71).png
# /kaggle/input/coffee-beans-saad/test/Light/light (45).png
# /kaggle/input/coffee-beans-saad/test/Light/light (19).png
# /kaggle/input/coffee-beans-saad/test/Light/light (14).png
# /kaggle/input/coffee-beans-saad/test/Light/light (93).png
# /kaggle/input/coffee-beans-saad/test/Light/light (32).png
# /kaggle/input/coffee-beans-saad/test/Light/light (68).png
# /kaggle/input/coffee-beans-saad/test/Light/light (52).png
# /kaggle/input/coffee-beans-saad/test/Light/light (80).png
# /kaggle/input/coffee-beans-saad/test/Light/light (26).png
# /kaggle/input/coffee-beans-saad/test/Light/light (90).png
# /kaggle/input/coffee-beans-saad/test/Light/light (99).png
# /kaggle/input/coffee-beans-saad/test/Light/light (35).png
# /kaggle/input/coffee-beans-saad/test/Light/light (48).png
# /kaggle/input/coffee-beans-saad/test/Light/light (97).png
# /kaggle/input/coffee-beans-saad/test/Light/light (92).png
# /kaggle/input/coffee-beans-saad/test/Light/light (10).png
# /kaggle/input/coffee-beans-saad/test/Light/light (55).png
# /kaggle/input/coffee-beans-saad/test/Light/light (23).png
# /kaggle/input/coffee-beans-saad/test/Light/light (64).png
# /kaggle/input/coffee-beans-saad/test/Light/light (79).png
# /kaggle/input/coffee-beans-saad/test/Light/light (91).png
# /kaggle/input/coffee-beans-saad/test/Light/light (33).png
# /kaggle/input/coffee-beans-saad/test/Light/light (29).png
# /kaggle/input/coffee-beans-saad/test/Light/light (18).png
# /kaggle/input/coffee-beans-saad/test/Light/light (88).png
# /kaggle/input/coffee-beans-saad/test/Light/light (9).png
# /kaggle/input/coffee-beans-saad/test/Light/light (44).png
# /kaggle/input/coffee-beans-saad/test/Light/light (53).png
# /kaggle/input/coffee-beans-saad/test/Light/light (54).png
# /kaggle/input/coffee-beans-saad/test/Light/light (94).png
# /kaggle/input/coffee-beans-saad/test/Light/light (24).png
# /kaggle/input/coffee-beans-saad/test/Light/light (96).png
# /kaggle/input/coffee-beans-saad/test/Light/light (17).png
# /kaggle/input/coffee-beans-saad/test/Light/light (67).png
# /kaggle/input/coffee-beans-saad/test/Light/light (34).png
# /kaggle/input/coffee-beans-saad/test/Light/light (13).png
# /kaggle/input/coffee-beans-saad/test/Light/light (30).png
# /kaggle/input/coffee-beans-saad/test/Light/light (62).png
# /kaggle/input/coffee-beans-saad/test/Light/light (57).png
# /kaggle/input/coffee-beans-saad/test/Light/light (16).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (79).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (5).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (89).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (36).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (20).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (22).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (88).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (62).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (66).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (82).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (27).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (48).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (71).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (6).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (40).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (93).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (83).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (14).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (60).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (78).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (26).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (90).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (77).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (43).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (41).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (32).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (42).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (45).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (12).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (3).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (8).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (13).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (58).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (34).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (95).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (50).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (23).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (46).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (16).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (29).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (96).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (91).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (49).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (56).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (100).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (94).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (21).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (15).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (67).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (61).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (74).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (33).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (51).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (52).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (17).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (81).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (99).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (68).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (84).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (9).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (37).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (28).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (59).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (25).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (44).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (2).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (65).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (7).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (92).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (72).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (10).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (54).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (57).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (73).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (76).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (98).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (97).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (70).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (38).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (35).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (1).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (53).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (47).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (69).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (30).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (64).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (24).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (86).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (18).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (31).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (63).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (87).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (75).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (39).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (19).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (80).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (4).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (55).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (11).png
# /kaggle/input/coffee-beans-saad/test/Medium/medium (85).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (194).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (189).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (186).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (2).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (95).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (190).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (283).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (45).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (292).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (8).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (196).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (83).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (15).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (228).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (98).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (142).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (91).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (165).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (113).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (22).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (235).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (23).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (109).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (236).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (158).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (143).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (233).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (75).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (55).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (168).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (105).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (11).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (144).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (203).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (281).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (39).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (211).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (100).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (33).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (79).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (243).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (231).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (173).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (256).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (260).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (157).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (44).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (273).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (48).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (108).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (21).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (244).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (297).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (25).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (247).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (129).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (265).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (103).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (110).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (287).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (261).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (43).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (257).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (76).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (57).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (210).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (62).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (4).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (299).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (46).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (277).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (285).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (24).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (136).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (162).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (207).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (134).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (59).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (180).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (217).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (99).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (84).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (214).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (102).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (153).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (284).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (290).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (88).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (251).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (159).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (237).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (115).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (9).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (49).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (279).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (197).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (259).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (169).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (93).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (138).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (145).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (172).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (171).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (127).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (141).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (225).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (286).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (58).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (240).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (264).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (3).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (182).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (17).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (193).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (176).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (135).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (80).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (293).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (35).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (1).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (164).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (86).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (125).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (68).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (295).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (289).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (250).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (200).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (296).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (34).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (195).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (155).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (271).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (245).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (29).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (147).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (65).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (120).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (154).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (87).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (215).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (178).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (160).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (121).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (56).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (267).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (119).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (126).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (38).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (30).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (282).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (137).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (47).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (117).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (42).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (111).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (18).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (41).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (241).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (184).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (132).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (254).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (72).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (288).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (53).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (74).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (101).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (163).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (291).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (226).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (112).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (37).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (124).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (63).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (167).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (19).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (66).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (26).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (181).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (187).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (276).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (268).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (104).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (27).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (218).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (212).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (152).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (85).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (13).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (262).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (170).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (246).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (270).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (253).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (179).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (222).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (133).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (131).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (255).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (274).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (223).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (78).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (252).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (82).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (40).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (130).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (161).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (280).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (232).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (199).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (69).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (230).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (7).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (227).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (107).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (269).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (242).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (50).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (266).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (61).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (114).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (156).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (177).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (216).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (139).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (122).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (219).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (97).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (16).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (224).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (150).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (166).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (175).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (202).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (294).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (20).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (146).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (31).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (205).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (192).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (96).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (116).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (220).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (272).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (198).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (6).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (204).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (52).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (191).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (174).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (148).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (298).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (209).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (73).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (81).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (10).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (140).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (12).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (151).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (149).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (67).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (208).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (263).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (234).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (128).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (258).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (123).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (221).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (248).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (188).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (201).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (106).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (185).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (51).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (32).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (239).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (249).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (36).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (92).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (70).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (77).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (28).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (183).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (206).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (71).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (213).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (5).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (64).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (229).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (90).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (278).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (275).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (238).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (60).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (14).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (89).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (118).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (94).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (300).png
# /kaggle/input/coffee-beans-saad/train/Dark/dark (54).png
# /kaggle/input/coffee-beans-saad/train/Green/green (138).png
# /kaggle/input/coffee-beans-saad/train/Green/green (290).png
# /kaggle/input/coffee-beans-saad/train/Green/green (17).png
# /kaggle/input/coffee-beans-saad/train/Green/green (248).png
# /kaggle/input/coffee-beans-saad/train/Green/green (99).png
# /kaggle/input/coffee-beans-saad/train/Green/green (154).png
# /kaggle/input/coffee-beans-saad/train/Green/green (47).png
# /kaggle/input/coffee-beans-saad/train/Green/green (81).png
# /kaggle/input/coffee-beans-saad/train/Green/green (271).png
# /kaggle/input/coffee-beans-saad/train/Green/green (87).png
# /kaggle/input/coffee-beans-saad/train/Green/green (109).png
# /kaggle/input/coffee-beans-saad/train/Green/green (158).png
# /kaggle/input/coffee-beans-saad/train/Green/green (98).png
# /kaggle/input/coffee-beans-saad/train/Green/green (8).png
# /kaggle/input/coffee-beans-saad/train/Green/green (30).png
# /kaggle/input/coffee-beans-saad/train/Green/green (5).png
# /kaggle/input/coffee-beans-saad/train/Green/green (200).png
# /kaggle/input/coffee-beans-saad/train/Green/green (69).png
# /kaggle/input/coffee-beans-saad/train/Green/green (226).png
# /kaggle/input/coffee-beans-saad/train/Green/green (284).png
# /kaggle/input/coffee-beans-saad/train/Green/green (207).png
# /kaggle/input/coffee-beans-saad/train/Green/green (26).png
# /kaggle/input/coffee-beans-saad/train/Green/green (122).png
# /kaggle/input/coffee-beans-saad/train/Green/green (206).png
# /kaggle/input/coffee-beans-saad/train/Green/green (278).png
# /kaggle/input/coffee-beans-saad/train/Green/green (199).png
# /kaggle/input/coffee-beans-saad/train/Green/green (130).png
# /kaggle/input/coffee-beans-saad/train/Green/green (112).png
# /kaggle/input/coffee-beans-saad/train/Green/green (297).png
# /kaggle/input/coffee-beans-saad/train/Green/green (171).png
# /kaggle/input/coffee-beans-saad/train/Green/green (251).png
# /kaggle/input/coffee-beans-saad/train/Green/green (25).png
# /kaggle/input/coffee-beans-saad/train/Green/green (105).png
# /kaggle/input/coffee-beans-saad/train/Green/green (274).png
# /kaggle/input/coffee-beans-saad/train/Green/green (50).png
# /kaggle/input/coffee-beans-saad/train/Green/green (197).png
# /kaggle/input/coffee-beans-saad/train/Green/green (114).png
# /kaggle/input/coffee-beans-saad/train/Green/green (260).png
# /kaggle/input/coffee-beans-saad/train/Green/green (123).png
# /kaggle/input/coffee-beans-saad/train/Green/green (288).png
# /kaggle/input/coffee-beans-saad/train/Green/green (121).png
# /kaggle/input/coffee-beans-saad/train/Green/green (104).png
# /kaggle/input/coffee-beans-saad/train/Green/green (296).png
# /kaggle/input/coffee-beans-saad/train/Green/green (43).png
# /kaggle/input/coffee-beans-saad/train/Green/green (258).png
# /kaggle/input/coffee-beans-saad/train/Green/green (83).png
# /kaggle/input/coffee-beans-saad/train/Green/green (196).png
# /kaggle/input/coffee-beans-saad/train/Green/green (253).png
# /kaggle/input/coffee-beans-saad/train/Green/green (193).png
# /kaggle/input/coffee-beans-saad/train/Green/green (6).png
# /kaggle/input/coffee-beans-saad/train/Green/green (139).png
# /kaggle/input/coffee-beans-saad/train/Green/green (54).png
# /kaggle/input/coffee-beans-saad/train/Green/green (100).png
# /kaggle/input/coffee-beans-saad/train/Green/green (198).png
# /kaggle/input/coffee-beans-saad/train/Green/green (283).png
# /kaggle/input/coffee-beans-saad/train/Green/green (184).png
# /kaggle/input/coffee-beans-saad/train/Green/green (41).png
# /kaggle/input/coffee-beans-saad/train/Green/green (214).png
# /kaggle/input/coffee-beans-saad/train/Green/green (134).png
# /kaggle/input/coffee-beans-saad/train/Green/green (188).png
# /kaggle/input/coffee-beans-saad/train/Green/green (88).png
# /kaggle/input/coffee-beans-saad/train/Green/green (116).png
# /kaggle/input/coffee-beans-saad/train/Green/green (215).png
# /kaggle/input/coffee-beans-saad/train/Green/green (228).png
# /kaggle/input/coffee-beans-saad/train/Green/green (160).png
# /kaggle/input/coffee-beans-saad/train/Green/green (176).png
# /kaggle/input/coffee-beans-saad/train/Green/green (236).png
# /kaggle/input/coffee-beans-saad/train/Green/green (162).png
# /kaggle/input/coffee-beans-saad/train/Green/green (57).png
# /kaggle/input/coffee-beans-saad/train/Green/green (182).png
# /kaggle/input/coffee-beans-saad/train/Green/green (108).png
# /kaggle/input/coffee-beans-saad/train/Green/green (186).png
# /kaggle/input/coffee-beans-saad/train/Green/green (35).png
# /kaggle/input/coffee-beans-saad/train/Green/green (277).png
# /kaggle/input/coffee-beans-saad/train/Green/green (263).png
# /kaggle/input/coffee-beans-saad/train/Green/green (218).png
# /kaggle/input/coffee-beans-saad/train/Green/green (289).png
# /kaggle/input/coffee-beans-saad/train/Green/green (42).png
# /kaggle/input/coffee-beans-saad/train/Green/green (103).png
# /kaggle/input/coffee-beans-saad/train/Green/green (183).png
# /kaggle/input/coffee-beans-saad/train/Green/green (293).png
# /kaggle/input/coffee-beans-saad/train/Green/green (85).png
# /kaggle/input/coffee-beans-saad/train/Green/green (65).png
# /kaggle/input/coffee-beans-saad/train/Green/green (286).png
# /kaggle/input/coffee-beans-saad/train/Green/green (212).png
# /kaggle/input/coffee-beans-saad/train/Green/green (64).png
# /kaggle/input/coffee-beans-saad/train/Green/green (145).png
# /kaggle/input/coffee-beans-saad/train/Green/green (102).png
# /kaggle/input/coffee-beans-saad/train/Green/green (169).png
# /kaggle/input/coffee-beans-saad/train/Green/green (252).png
# /kaggle/input/coffee-beans-saad/train/Green/green (237).png
# /kaggle/input/coffee-beans-saad/train/Green/green (1).png
# /kaggle/input/coffee-beans-saad/train/Green/green (178).png
# /kaggle/input/coffee-beans-saad/train/Green/green (255).png
# /kaggle/input/coffee-beans-saad/train/Green/green (13).png
# /kaggle/input/coffee-beans-saad/train/Green/green (32).png
# /kaggle/input/coffee-beans-saad/train/Green/green (225).png
# /kaggle/input/coffee-beans-saad/train/Green/green (203).png
# /kaggle/input/coffee-beans-saad/train/Green/green (220).png
# /kaggle/input/coffee-beans-saad/train/Green/green (234).png
# /kaggle/input/coffee-beans-saad/train/Green/green (249).png
# /kaggle/input/coffee-beans-saad/train/Green/green (66).png
# /kaggle/input/coffee-beans-saad/train/Green/green (59).png
# /kaggle/input/coffee-beans-saad/train/Green/green (92).png
# /kaggle/input/coffee-beans-saad/train/Green/green (201).png
# /kaggle/input/coffee-beans-saad/train/Green/green (202).png
# /kaggle/input/coffee-beans-saad/train/Green/green (224).png
# /kaggle/input/coffee-beans-saad/train/Green/green (190).png
# /kaggle/input/coffee-beans-saad/train/Green/green (264).png
# /kaggle/input/coffee-beans-saad/train/Green/green (29).png
# /kaggle/input/coffee-beans-saad/train/Green/green (68).png
# /kaggle/input/coffee-beans-saad/train/Green/green (240).png
# /kaggle/input/coffee-beans-saad/train/Green/green (268).png
# /kaggle/input/coffee-beans-saad/train/Green/green (44).png
# /kaggle/input/coffee-beans-saad/train/Green/green (9).png
# /kaggle/input/coffee-beans-saad/train/Green/green (31).png
# /kaggle/input/coffee-beans-saad/train/Green/green (39).png
# /kaggle/input/coffee-beans-saad/train/Green/green (191).png
# /kaggle/input/coffee-beans-saad/train/Green/green (287).png
# /kaggle/input/coffee-beans-saad/train/Green/green (265).png
# /kaggle/input/coffee-beans-saad/train/Green/green (133).png
# /kaggle/input/coffee-beans-saad/train/Green/green (3).png
# /kaggle/input/coffee-beans-saad/train/Green/green (221).png
# /kaggle/input/coffee-beans-saad/train/Green/green (118).png
# /kaggle/input/coffee-beans-saad/train/Green/green (74).png
# ...
# /kaggle/input/coffee-beans-saad/train/Medium/medium (295).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (298).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (6).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (286).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (278).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (157).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (148).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (294).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (40).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (191).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (107).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (214).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (93).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (83).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (14).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (194).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (119).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (60).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (261).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (187).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (78).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (163).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (240).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (208).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (26).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (90).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (207).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (192).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (156).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (111).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (244).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (231).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (267).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (238).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (133).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (195).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (77).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (164).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (166).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (141).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (282).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (105).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (43).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (132).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (41).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (32).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (42).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (276).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (204).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (288).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (45).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (12).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (265).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (146).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (106).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (108).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (3).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (113).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (165).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (211).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (296).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (159).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (8).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (197).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (280).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (220).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (169).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (167).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (279).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (139).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (128).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (151).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (184).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (129).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (116).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (13).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (274).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (155).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (177).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (104).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (250).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (140).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (58).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (283).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (260).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (34).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (118).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (245).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (95).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (252).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (263).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (50).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (23).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (138).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (206).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (46).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (178).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (16).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (273).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (143).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (29).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (235).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (213).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (285).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (242).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (96).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (161).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (246).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (91).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (145).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (49).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (56).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (100).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (94).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (249).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (228).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (189).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (21).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (223).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (15).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (275).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (120).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (67).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (190).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (122).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (137).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (248).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (230).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (61).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (74).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (205).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (33).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (51).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (52).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (17).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (196).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (81).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (158).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (297).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (266).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (254).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (127).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (103).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (299).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (144).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (99).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (68).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (202).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (84).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (255).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (170).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (114).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (9).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (121).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (237).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (289).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (293).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (173).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (37).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (160).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (28).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (59).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (193).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (25).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (44).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (256).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (2).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (198).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (179).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (124).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (284).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (65).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (7).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (92).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (72).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (10).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (54).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (239).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (57).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (277).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (73).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (269).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (201).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (162).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (76).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (270).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (226).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (264).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (98).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (97).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (300).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (102).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (186).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (183).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (218).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (70).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (236).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (38).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (150).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (35).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (227).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (222).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (258).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (1).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (181).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (219).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (53).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (200).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (176).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (292).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (290).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (247).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (123).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (221).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (216).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (185).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (47).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (131).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (69).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (126).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (30).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (203).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (64).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (117).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (24).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (199).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (212).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (241).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (86).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (18).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (31).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (234).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (153).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (63).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (215).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (259).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (217).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (87).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (262).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (281).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (182).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (243).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (101).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (75).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (229).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (115).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (224).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (149).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (251).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (39).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (268).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (19).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (80).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (4).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (55).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (11).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (188).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (147).png
# /kaggle/input/coffee-beans-saad/train/Medium/medium (85).png

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import torch
import torch.nn as nn
from torchvision import models, transforms

from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier

# %%
base_dir = "/kaggle/input/coffee-beans-saad"

def create_dataframe(data_dir):
    file_paths, labels = [], []
    for class_name in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, class_name)
        if not os.path.isdir(class_dir):
            continue
        for image_name in os.listdir(class_dir):
            file_paths.append(os.path.join(class_dir, image_name))
            labels.append(class_name)
    df = pd.DataFrame({"file_path": file_paths, "label": labels})
    return df.sample(frac=1).reset_index(drop=True)

train_df = create_dataframe(os.path.join(base_dir, "train"))
test_df = create_dataframe(os.path.join(base_dir, "test"))

print("Train size:", len(train_df))
print("Test size:", len(test_df))
train_df.head()
# Out:
# Train size: 1200
# Test size: 400
#                                            file_path   label
# 0  /kaggle/input/coffee-beans-saad/train/Light/li...   Light
# 1  /kaggle/input/coffee-beans-saad/train/Medium/m...  Medium
# 2  /kaggle/input/coffee-beans-saad/train/Light/li...   Light
# 3  /kaggle/input/coffee-beans-saad/train/Green/gr...   Green
# 4  /kaggle/input/coffee-beans-saad/train/Dark/dar...    Dark

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn_model = models.resnet50(pretrained=True)
cnn_model.fc = nn.Identity()  # remove final classification layer
cnn_model.to(device)
cnn_model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Identity()
# )

# %%
def extract_features(df, transform_type):
    features, labels = [], []
    for _, row in df.iterrows():
        image = Image.open(row["file_path"]).convert("RGB")
        image = transform_type(image).unsqueeze(0).to(device)
        with torch.no_grad():
            feat = cnn_model(image).cpu().numpy().flatten()
        features.append(feat)
        labels.append(row["label"])
    return np.array(features), np.array(labels)

print("Extracting training features...")
X_train, y_train = extract_features(train_df, train_transform)
print("Extracting test features...")
X_test, y_test = extract_features(test_df, test_transform)

print("Train features shape:", X_train.shape)
print("Test features shape:", X_test.shape)
# Out:
# Extracting training features...
# Extracting test features...
# Train features shape: (1200, 2048)
# Test features shape: (400, 2048)

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)
class_names = le.classes_
print("Classes:", class_names)
# Out:
# Classes: ['Dark' 'Green' 'Light' 'Medium']

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_metrics_knn = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train_enc), 1):
    print(f"\n===== Fold {fold} =====")
    X_tr, X_val = X_train[train_idx], X_train[val_idx]
    y_tr, y_val = y_train_enc[train_idx], y_train_enc[val_idx]
    
    start_time = time.time()
    knn_model = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
    knn_model.fit(X_tr, y_tr)
    train_time = time.time() - start_time
    
    # Evaluate on validation set
    y_val_pred = knn_model.predict(X_val)
    y_val_prob = knn_model.predict_proba(X_val)
    
    accuracy = accuracy_score(y_val, y_val_pred)
    auc = roc_auc_score(label_binarize(y_val, classes=range(len(class_names))), y_val_prob, multi_class="ovr")
    
    print(f"Accuracy: {accuracy:.4f}, AUC: {auc:.4f}, Training Time: {train_time:.2f} sec")
    fold_metrics_knn.append({"fold": fold, "accuracy": accuracy, "auc": auc, "train_time": train_time})

# Average metrics across folds
avg_accuracy_knn = np.mean([m["accuracy"] for m in fold_metrics_knn])
avg_auc_knn = np.mean([m["auc"] for m in fold_metrics_knn])
avg_time_knn = np.mean([m["train_time"] for m in fold_metrics_knn])

print(f"\n===== Average Metrics Across 5 Folds (k-NN) =====")
print(f"Accuracy: {avg_accuracy_knn:.4f}, AUC: {avg_auc_knn:.4f}, Avg Training Time: {avg_time_knn:.2f} sec")
# Out:
# ===== Fold 1 =====
# Accuracy: 0.8667, AUC: 0.9723, Training Time: 0.00 sec
#
# ===== Fold 2 =====
# Accuracy: 0.8708, AUC: 0.9743, Training Time: 0.00 sec
#
# ===== Fold 3 =====
# Accuracy: 0.8958, AUC: 0.9677, Training Time: 0.00 sec
#
# ===== Fold 4 =====
# Accuracy: 0.8417, AUC: 0.9610, Training Time: 0.00 sec
#
# ===== Fold 5 =====
# Accuracy: 0.8625, AUC: 0.9702, Training Time: 0.00 sec
#
# ===== Average Metrics Across 5 Folds (k-NN) =====
# Accuracy: 0.8675, AUC: 0.9691, Avg Training Time: 0.00 sec

# %%
knn_model_final = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
knn_model_final.fit(X_train, y_train_enc)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
y_pred_knn = knn_model_final.predict(X_test)
y_prob_knn = knn_model_final.predict_proba(X_test)

accuracy_knn = accuracy_score(y_test_enc, y_pred_knn)
print(f"\nTest Accuracy (k-NN): {accuracy_knn:.4f}")
print(classification_report(y_test_enc, y_pred_knn, target_names=class_names))

# Confusion Matrix
cm_knn = confusion_matrix(y_test_enc, y_pred_knn)
plt.figure(figsize=(6,5))
sns.heatmap(cm_knn, annot=True, fmt="d", cmap="Oranges",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (k-NN Final Model)")
plt.show()

# ROC & AUC
y_test_bin = label_binarize(y_test_enc, classes=range(len(class_names)))
auc_knn = roc_auc_score(y_test_bin, y_prob_knn, multi_class="ovr")
print(f"Test AUC (k-NN): {auc_knn:.4f}")

# ROC Curve
plt.figure(figsize=(8,6))
for i, class_name in enumerate(class_names):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_prob_knn[:, i])
    plt.plot(fpr, tpr, label=f"{class_name}")
plt.plot([0,1], [0,1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (k-NN Final Model)")
plt.legend()
plt.show()
# Out:
# Test Accuracy (k-NN): 0.8925
#               precision    recall  f1-score   support
#
#         Dark       0.88      0.90      0.89       100
#        Green       0.96      0.96      0.96       100
#        Light       0.93      0.87      0.90       100
#       Medium       0.81      0.84      0.82       100
#
#     accuracy                           0.89       400
#    macro avg       0.89      0.89      0.89       400
# weighted avg       0.89      0.89      0.89       400
# Test AUC (k-NN): 0.9800
